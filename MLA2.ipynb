# %% [markdown]
# # Titanic

# %%
import pandas as pd
import seaborn as sns # importing sea born library
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
import random as rnd
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC, LinearSVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import Perceptron
from sklearn.linear_model import SGDClassifier
from sklearn.tree import DecisionTreeClassifier
import seaborn as sns

# %% [markdown]
# # Import Data from the existing Data

# %%
train_df=pd.read_csv("D:\\MLA\\titanic\\train.csv")

# %%
train_df.head(1)
# Out:
#    PassengerId  Survived  Pclass                     Name   Sex   Age  SibSp  \
# 0            1         0       3  Braund, Mr. Owen Harris  male  22.0      1
#
#    Parch     Ticket  Fare Cabin Embarked
# 0      0  A/5 21171  7.25   NaN        S

# %%
test_df=pd.read_csv("D:\\MLA\\titanic\\test.csv")

# %%
test_df.head(1)
# Out:
#    PassengerId  Pclass              Name   Sex   Age  SibSp  Parch  Ticket  \
# 0          892       3  Kelly, Mr. James  male  34.5      0      0  330911
#
#      Fare Cabin Embarked
# 0  7.8292   NaN        Q

# %% [markdown]
# #   Exploratory data analysis

# %%
train_df.nunique()
# Out:
# PassengerId    891
# Survived         2
# Pclass           3
# Name           891
# Sex              2
# Age             88
# SibSp            7
# Parch            7
# Ticket         681
# Fare           248
# Cabin          147
# Embarked         3
# dtype: int64

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.6+ KB

# %%
train_df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
test_df.nunique()
# Out:
# PassengerId    418
# Pclass           3
# Name           418
# Sex              2
# Age             79
# SibSp            7
# Parch            8
# Ticket         363
# Fare           169
# Cabin           76
# Embarked         3
# dtype: int64

# %%
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 11 columns):
# PassengerId    418 non-null int64
# Pclass         418 non-null int64
# Name           418 non-null object
# Sex            418 non-null object
# Age            332 non-null float64
# SibSp          418 non-null int64
# Parch          418 non-null int64
# Ticket         418 non-null object
# Fare           417 non-null float64
# Cabin          91 non-null object
# Embarked       418 non-null object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 36.0+ KB

# %%
test_df.isnull().sum()
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
train_df['Age']=train_df['Age'].fillna(train_df['Age'].mean())
train_df['Age']=train_df['Age'].astype("int")

# %%
test_df['Age']=test_df['Age'].fillna(test_df['Age'].mean())
test_df['Age']=test_df['Age'].astype("int")

# %%
train_df['Embarked']=train_df['Embarked'].fillna("train_df['Embarked'].mode()")

# %%
test_df['Fare']=test_df['Fare'].fillna(test_df['Fare'].mean())
test_df['Fare']=test_df['Fare'].astype("int")
train_df['Fare']=train_df['Fare'].astype("int")

# %%
train_df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         0
# dtype: int64

# %%
test_df.isnull().sum()
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          327
# Embarked         0
# dtype: int64

# %%
train_X = train_df[['Survived','Pclass','Sex','Age','SibSp','Parch','Fare','Embarked']]
test_X =train_df[['Pclass','Sex','Age','SibSp','Parch','Fare','Embarked']]
train_Y=train_df['Survived']

# %%
train_X.head(1)
train_X.nunique()
# Out:
# Survived     2
# Pclass       3
# Sex          2
# Age         71
# SibSp        7
# Parch        7
# Fare        91
# Embarked     4
# dtype: int64

# %%
train_X.describe(include ="all")
# Out:
#           Survived      Pclass   Sex         Age       SibSp       Parch  \
# count   891.000000  891.000000   891  891.000000  891.000000  891.000000
# unique         NaN         NaN     2         NaN         NaN         NaN
# top            NaN         NaN  male         NaN         NaN         NaN
# freq           NaN         NaN   577         NaN         NaN         NaN
# mean      0.383838    2.308642   NaN   29.544332    0.523008    0.381594
# std       0.486592    0.836071   NaN   13.013778    1.102743    0.806057
# min       0.000000    1.000000   NaN    0.000000    0.000000    0.000000
# 25%       0.000000    2.000000   NaN   22.000000    0.000000    0.000000
# 50%       0.000000    3.000000   NaN   29.000000    0.000000    0.000000
# 75%       1.000000    3.000000   NaN   35.000000    1.000000    0.000000
# max       1.000000    3.000000   NaN   80.000000    8.000000    6.000000
#
#               Fare Embarked
# count   891.000000      891
# unique         NaN        4
# ...

# %%
train_X.corr()
# Out:
#           Survived    Pclass       Age     SibSp     Parch      Fare
# Survived  1.000000 -0.338481 -0.067809 -0.035322  0.081629  0.257482
# Pclass   -0.338481  1.000000 -0.335071  0.083081  0.018443 -0.550553
# Age      -0.067809 -0.335071  1.000000 -0.232743 -0.176744  0.094069
# SibSp    -0.035322  0.083081 -0.232743  1.000000  0.414838  0.159506
# Parch     0.081629  0.018443 -0.176744  0.414838  1.000000  0.216252
# Fare      0.257482 -0.550553  0.094069  0.159506  0.216252  1.000000

# %%
combine = [train_X, test_X]

# %%
train_X
# Out:
#      Survived  Pclass     Sex  Age  SibSp  Parch  Fare Embarked
# 0           0       3    male   22      1      0     7        S
# 1           1       1  female   38      1      0    71        C
# 2           1       3  female   26      0      0     7        S
# 3           1       1  female   35      1      0    53        S
# 4           0       3    male   35      0      0     8        S
# 5           0       3    male   29      0      0     8        Q
# 6           0       1    male   54      0      0    51        S
# 7           0       3    male    2      3      1    21        S
# 8           1       3  female   27      0      2    11        S
# 9           1       2  female   14      1      0    30        C
# 10          1       3  female    4      1      1    16        S
# 11          1       1  female   58      0      0    26        S
# 12          0       3    male   20      0      0     8        S
# 13          0       3    male   39      1      5    31        S
# ...

# %%
for dataset in combine:
    dataset['Sex'] = dataset['Sex'].map( {'female': 1, 'male': 0} ).astype(int)
# Out:
# C:\anaconda\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
for dataset in combine:
    dataset['Embarked'] = dataset['Embarked'].map( {'S': 0, 'C': 1, 'Q': 2} ).astype("int")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-67-1467a437c086> in <module>
#       1 for dataset in combine:
# ----> 2     dataset['Embarked'] = dataset['Embarked'].map( {'S': 0, 'C': 1, 'Q': 2} ).astype("int")
#       3
#
# C:\anaconda\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors, **kwargs)
#    5689             # else, only a single dtype is given
#    5690             new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors,
# -> 5691                                          **kwargs)
#    5692             return self._constructor(new_data).__finalize__(self)
#    5693
#
# C:\anaconda\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, **kwargs)
#     529
#     530     def astype(self, dtype, **kwargs):
# --> 531         return self.apply('astype', dtype=dtype, **kwargs)
#     532
# ...

# %%
Linear_Reg=LinearRegression()
Linear_Reg.fit(train_X,train_Y)
test_Y=Linear_Reg.Predict(test_X)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-42-19ccee095d2a> in <module>
#       1 Linear_Reg=LinearRegression()
# ----> 2 Linear_Reg.fit(train_X,train_Y)
#       3 test_Y=Linear_Reg.Predict(test_X)
#
# C:\anaconda\lib\site-packages\sklearn\linear_model\base.py in fit(self, X, y, sample_weight)
#     461         n_jobs_ = self.n_jobs
#     462         X, y = check_X_y(X, y, accept_sparse=['csr', 'csc', 'coo'],
# --> 463                          y_numeric=True, multi_output=True)
#     464
#     465         if sample_weight is not None and np.atleast_1d(sample_weight).ndim > 1:
#
# C:\anaconda\lib\site-packages\sklearn\utils\validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
# ...

# %%
linear_svc = LinearSVC()
linear_svc.fit(X_train, Y_train)
Y_pred = linear_svc.predict(X_test)
#acc_linear_svc = round(linear_svc.score(X_train, Y_train) * 100, 2)
#acc_linear_svc
Y_pred
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-39-69bee152a77d> in <module>
# ----> 1 linear_svc = LinearSVC()
#       2 linear_svc.fit(X_train, Y_train)
#       3 Y_pred = linear_svc.predict(X_test)
#       4 #acc_linear_svc = round(linear_svc.score(X_train, Y_train) * 100, 2)
#       5 #acc_linear_svc
#
# NameError: name 'LinearSVC' is not defined

# %%
knn = KNeighborsClassifier(n_neighbors = 3)
knn.fit(X_train, Y_train)
Y_pred = knn.predict(X_test)
acc_knn = round(knn.score(X_train, Y_train) * 100, 2)
acc_knn

# %%
svc = SVC()
svc.fit(X_train, Y_train)
Y_pred = svc.predict(X_test)
acc_svc = round(svc.score(X_train, Y_train) * 100, 2)
acc_svc

# %%
decision_tree = DecisionTreeClassifier()
decision_tree.fit(X_train, Y_train)
Y_pred = decision_tree.predict(X_test)
acc_decision_tree = round(decision_tree.score(X_train, Y_train) * 100, 2)
acc_decision_tree

# %%
random_forest = RandomForestClassifier(n_estimators=100)
random_forest.fit(X_train, Y_train)
Y_pred = random_forest.predict(X_test)
random_forest.score(X_train, Y_train)
acc_random_forest = round(random_forest.score(X_train, Y_train) * 100, 2)
acc_random_forest

# %%
models = pd.DataFrame({
    'Model': ['Support Vector Machines', 'KNN','Random Forest','Linear SVC', 'Decision Tree'],
    'Score': [acc_svc, acc_knn, acc_random_forest,acc_linear_svc, acc_decision_tree]})
models.sort_values(by='Score', ascending=False)
